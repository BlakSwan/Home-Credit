# %%
import mlflow
from mlflow.models import infer_signature
from config import run_name
import polars as pl
import numpy as np
import pandas as pd
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score 
import warnings
import os
import re

warnings.filterwarnings('ignore')

dataPath = "/Users/chrisjackson/Downloads/home-credit-credit-risk-model-stability/"

# %% [markdown]
# ## Define an MLflow Experiment
#
# In order to group any distinct runs of a particular project or idea together, we can define an Experiment that will group each iteration (runs) together.
# Defining a unique name that is relevant to what we're working on helps with organization and reduces the amount of work (searching) to find our runs later on.

# %%
# NOTE: review the links mentioned above for guidance on connecting to a managed tracking server, such as the free Databricks Community Edition

mlflow.set_tracking_uri(uri="http://127.0.0.1:8080")

### NOTE:RUN THIS IN BASH TO START MLFLOW TRACKING SERVER ###
# mlflow server --host 127.0.0.1 --port 8080

# %%
def get_or_create_experiment(experiment_name):
    """
    Retrieve the ID of an existing MLflow experiment or create a new one if it doesn't exist.

    This function checks if an experiment with the given name exists within MLflow.
    If it does, the function returns its ID. If not, it creates a new experiment
    with the provided name and returns its ID.

    Parameters:
    - experiment_name (str): Name of the MLflow experiment.

    Returns:
    - str: ID of the existing or newly created MLflow experiment.
    """

    if experiment := mlflow.get_experiment_by_name(experiment_name):
        return experiment.experiment_id
    else:
        return mlflow.create_experiment(experiment_name)

# %%
experiment_id = get_or_create_experiment("MLflow Home Credit Test")

# %% [markdown]
# ## Data Cleaning and Aggregation

# %%
class Pipeline:
    @staticmethod
    def set_table_dtypes(df): #Standardize the dtype.
        for col in df.columns:
            if col in ["case_id", "WEEK_NUM", "num_group1", "num_group2"]:
                df = df.with_columns(pl.col(col).cast(pl.Int64))
            elif col in ["date_decision"]:
                df = df.with_columns(pl.col(col).cast(pl.Date))
            elif col[-1] in ("P", "A"):
                df = df.with_columns(pl.col(col).cast(pl.Float64))
            elif col[-1] in ("M",):
                df = df.with_columns(pl.col(col).cast(pl.String))
            elif col[-1] in ("D",):
                df = df.with_columns(pl.col(col).cast(pl.Date))            

        return df
    
    @staticmethod
    def convert_strings(df: pd.DataFrame) -> pd.DataFrame:
        for col in df.columns:  
            if df[col].dtype.name in ['object', 'string']:
                df[col] = df[col].astype("string").astype('category')
                current_categories = df[col].cat.categories
                new_categories = current_categories.to_list() + ["Unknown"]
                new_dtype = pd.CategoricalDtype(categories=new_categories, ordered=True)
                df[col] = df[col].astype(new_dtype)
        return df
    
    @staticmethod
    def handle_dates(df): #Change the feature for D to the difference in days from date_decision.
        for col in df.columns:
            if col[-1] in ("D",):
                df = df.with_columns(pl.col(col) - pl.col("date_decision"))
                df = df.with_columns(pl.col(col).dt.total_days())
                
        df = df.drop("date_decision", "MONTH")

        return df
    
    @staticmethod
    def filter_cols(df): #Remove those with an average is_null exceeding 0.95 and those that do not fall within the range 1 < nunique < 200.
        for col in df.columns:
            if col not in ["target", "case_id", "WEEK_NUM"]:
                isnull = df[col].is_null().mean()

                if isnull > 0.95:
                    df = df.drop(col)

        for col in df.columns:
            if (col not in ["target", "case_id", "WEEK_NUM"]) & (df[col].dtype == pl.String):
                freq = df[col].n_unique()

                if (freq == 1) | (freq > 200):
                    df = df.drop(col)

        return df

# %%
feature_def = pl.read_csv(dataPath + "feature_definitions.csv")

basetable = pl.read_parquet(dataPath + "parquet_files/train/train_base.parquet")

# %%
def data_agg(depth=0, test_train='train') -> pl.DataFrame:
    # List all files in the folder
    all_files = os.listdir(dataPath + f"parquet_files/{test_train}/")

    # Filter files where the first number in the filename is depth
    filtered_files = []
    for file in all_files:
        digit = re.search(r'\d+', file)
        if digit and digit.group() == str(depth):
            filtered_files.append(file)
    
    
    # Read the base table
    aggregated_df = pl.read_parquet(dataPath + f"parquet_files/{test_train}/train_base.parquet")
    # Add the static tables to the aggregated_df, meaning the first number in the file name is 0 and they should be listed in filetred_files
    for file in filtered_files:
        df = pl.read_parquet(dataPath + f"parquet_files/{test_train}/{file}")
        print(file)

        # Join the aggregated results to the overall aggregated dataframe using the case_id column as the index
        aggregated_df = aggregated_df.join(df, on="case_id", how="left")
    
    # The columns with right in the name might contain info not in the non-right columns.  We need to combine them into one column
    # First we need to find the columns with right in the name
    right_columns = [col for col in aggregated_df.columns if "right" in col]
    # Then we need to find the columns without right in the name
    non_right_columns = [col for col in aggregated_df.columns if "right" not in col]
    # We need to iterate over the right columns and add them to the non-right columns and pick the non-null value
    for col in right_columns:
        # Print out how many null values there are in the right column
        print(f"Number of null values in {col}: {aggregated_df[col].is_null().sum()}")
        # Find the non-right column that corresponds to the right column
        non_right_col = col.replace("_right", "")
        # Print out how many null values there are in the non-right column
        print(f"Number of null values in {non_right_col}: {aggregated_df[non_right_col].is_null().sum()}")
        # Add the non-right column to the aggregated_df if the non-right column is null
        aggregated_df = aggregated_df.with_columns(
        pl.when(pl.col(non_right_col).is_null())
        .then(pl.col(col))
        .otherwise(pl.col(non_right_col))
        .alias(non_right_col)
        )
        # Print out how many null values there are in the non-right column after the change
        print(f"Number of null values in the combined {non_right_col}: {aggregated_df[non_right_col].is_null().sum()}")
    # We need to drop the right columns
    aggregated_df = aggregated_df.drop(right_columns)
    
    # Process the data with the Pipeline class
    aggregated_df = Pipeline.set_table_dtypes(aggregated_df)
    aggregated_df = Pipeline.handle_dates(aggregated_df)
    aggregated_df = Pipeline.filter_cols(aggregated_df)
    
    # If the depth is 1, then we are interested in the base tables and the tables with a depth of 1
    # if depth == 1:
    #     # As a test lets try to count the number of applications for each case_id
    #     # Gather the files with a depth of 1
    #     depth_1_files = [file for file in filtered_files if file[0] == "1"]
    #     return aggregated_df

    
    # # Remove basetable from the list of parquet files
    # parquet_files = [file for file in parquet_files if file != "train_base.parquet"]
    
    # # Iterate over each parquet file
    # for file in parquet_files:
    #     # Read the parquet file
    #     df = pl.read_parquet(os.path.join(dataPath, file))
        
    #     # Check if the file contains the column num_group1 and is a file with a depth of 1
    #     if "num_group1" in df.columns and "num_group2" not in df.columns:

    #         # Remove the num_group1 column
    #         df = df.drop("num_group1")
            # Join the aggregated results to the overall aggregated dataframe using the case_id column as the index
    #         aggregated_df = aggregated_df.join(df, on="case_id", how="outer")
        
    #     # Check if the file contains the column num_group1 and num_group2 and is a file with a depth of 2
    #     elif "num_group1" in df.columns and "num_group2" in df.columns and num_group2 is not None:
            # # Check if the aggregated df has the num_group1 and num_group2 columns
            # if "num_group2" not in aggregated_df.columns:
            #     # Add the num_group2 column to the aggregated_df
            #     aggregated_df = aggregated_df.join(df, on="case_id", how="outer")
            # # Filter for the desired num_group1 and num_group2 values
            # df = df.filter(pl.col("num_group1") == num_goup1).filter(pl.col("num_group2") == num_group2)
            # # Remove the num_group1 and num_group2 columns
            # df = df.drop("num_group1").drop("num_group2")
            # # Join the aggregated results to the overall aggregated dataframe using the case_id column as the index
            # aggregated_df = aggregated_df.join(df, on="case_id", how="outer")
        
    return aggregated_df

# %%
data = data_agg(0, 'train')
# Out:
# train_static_0_0.parquet
# train_static_0_1.parquet
# train_static_cb_0.parquet
# Number of null values in actualdpdtolerance_344P_right: 1125249
# Number of null values in actualdpdtolerance_344P: 819588
# Number of null values in the combined actualdpdtolerance_344P: 418178
# Number of null values in amtinstpaidbefduel24m_4187115A_right: 1136027
# Number of null values in amtinstpaidbefduel24m_4187115A: 951756
# Number of null values in the combined amtinstpaidbefduel24m_4187115A: 561124
# Number of null values in annuity_780A_right: 1003757
# Number of null values in annuity_780A: 522902
# Number of null values in the combined annuity_780A: 0
# Number of null values in annuitynextmonth_57A_right: 1003759
# Number of null values in annuitynextmonth_57A: 522904
# Number of null values in the combined annuitynextmonth_57A: 4
# Number of null values in applicationcnt_361L_right: 1003757
# Number of null values in applicationcnt_361L: 522902
# Number of null values in the combined applicationcnt_361L: 0
# Number of null values in applications30d_658L_right: 1003757
# Number of null values in applications30d_658L: 522902
# Number of null values in the combined applications30d_658L: 0
# Number of null values in applicationscnt_1086L_right: 1003757
# Number of null values in applicationscnt_1086L: 522902
# Number of null values in the combined applicationscnt_1086L: 0
# Number of null values in applicationscnt_464L_right: 1003757
# Number of null values in applicationscnt_464L: 522902
# Number of null values in the combined applicationscnt_464L: 0
# Number of null values in applicationscnt_629L_right: 1003757
# Number of null values in applicationscnt_629L: 522902
# Number of null values in the combined applicationscnt_629L: 0
# Number of null values in applicationscnt_867L_right: 1003757
# Number of null values in applicationscnt_867L: 522902
# Number of null values in the combined applicationscnt_867L: 0
# Number of null values in avgdbddpdlast24m_3658932P_right: 1190828
# Number of null values in avgdbddpdlast24m_3658932P: 949033
# Number of null values in the combined avgdbddpdlast24m_3658932P: 613202
# Number of null values in avgdbddpdlast3m_4187120P_right: 1293998
# Number of null values in avgdbddpdlast3m_4187120P: 1180905
# Number of null values in the combined avgdbddpdlast3m_4187120P: 948244
# Number of null values in avgdbdtollast24m_4525197P_right: 1190859
# Number of null values in avgdbdtollast24m_4525197P: 1308627
# Number of null values in the combined avgdbdtollast24m_4525197P: 972827
# Number of null values in avgdpdtolclosure24_3658938P_right: 1141660
# Number of null values in avgdpdtolclosure24_3658938P: 852174
# Number of null values in the combined avgdpdtolclosure24_3658938P: 467175
# Number of null values in avginstallast24m_3658937A_right: 1194911
# Number of null values in avginstallast24m_3658937A: 956623
# Number of null values in the combined avginstallast24m_3658937A: 624875
# Number of null values in avglnamtstart24m_4525187A_right: 1433957
# Number of null values in avglnamtstart24m_4525187A: 1456852
# Number of null values in the combined avglnamtstart24m_4525187A: 1364150
# Number of null values in avgmaxdpdlast9m_3716943P_right: 1245470
# Number of null values in avgmaxdpdlast9m_3716943P: 1038195
# Number of null values in the combined avgmaxdpdlast9m_3716943P: 757006
# Number of null values in avgoutstandbalancel6m_4187114A_right: 1245944
# Number of null values in avgoutstandbalancel6m_4187114A: 1121896
# Number of null values in the combined avgoutstandbalancel6m_4187114A: 841181
# Number of null values in avgpmtlast12m_4525200A_right: 1223434
# Number of null values in avgpmtlast12m_4525200A: 1330212
# Number of null values in the combined avgpmtlast12m_4525200A: 1026987
# Number of null values in bankacctype_710L_right: 1414319
# Number of null values in bankacctype_710L: 1221969
# Number of null values in the combined bankacctype_710L: 1109629
# Number of null values in cardtype_51L_right: 1460752
# Number of null values in cardtype_51L: 1400875
# Number of null values in the combined cardtype_51L: 1334968
# Number of null values in clientscnt12m_3712952L_right: 1003757
# Number of null values in clientscnt12m_3712952L: 522902
# Number of null values in the combined clientscnt12m_3712952L: 0
# Number of null values in clientscnt3m_3712950L_right: 1003757
# Number of null values in clientscnt3m_3712950L: 522902
# Number of null values in the combined clientscnt3m_3712950L: 0
# Number of null values in clientscnt6m_3712949L_right: 1003757
# Number of null values in clientscnt6m_3712949L: 522902
# Number of null values in the combined clientscnt6m_3712949L: 0
# Number of null values in clientscnt_100L_right: 1003757
# Number of null values in clientscnt_100L: 522902
# Number of null values in the combined clientscnt_100L: 0
# Number of null values in clientscnt_1022L_right: 1003757
# Number of null values in clientscnt_1022L: 522902
# Number of null values in the combined clientscnt_1022L: 0
# Number of null values in clientscnt_1071L_right: 1003757
# Number of null values in clientscnt_1071L: 522902
# Number of null values in the combined clientscnt_1071L: 0
# Number of null values in clientscnt_1130L_right: 1003757
# Number of null values in clientscnt_1130L: 522902
# Number of null values in the combined clientscnt_1130L: 0
# Number of null values in clientscnt_136L_right: 1526639
# Number of null values in clientscnt_136L: 1526262
# Number of null values in the combined clientscnt_136L: 1526242
# Number of null values in clientscnt_157L_right: 1003757
# Number of null values in clientscnt_157L: 522902
# Number of null values in the combined clientscnt_157L: 0
# Number of null values in clientscnt_257L_right: 1003757
# Number of null values in clientscnt_257L: 522902
# Number of null values in the combined clientscnt_257L: 0
# Number of null values in clientscnt_304L_right: 1003757
# Number of null values in clientscnt_304L: 522902
# Number of null values in the combined clientscnt_304L: 0
# Number of null values in clientscnt_360L_right: 1003757
# Number of null values in clientscnt_360L: 522902
# Number of null values in the combined clientscnt_360L: 0
# Number of null values in clientscnt_493L_right: 1003757
# Number of null values in clientscnt_493L: 522902
# Number of null values in the combined clientscnt_493L: 0
# Number of null values in clientscnt_533L_right: 1003757
# Number of null values in clientscnt_533L: 522902
# Number of null values in the combined clientscnt_533L: 0
# Number of null values in clientscnt_887L_right: 1003757
# Number of null values in clientscnt_887L: 522902
# Number of null values in the combined clientscnt_887L: 0
# Number of null values in clientscnt_946L_right: 1003757
# Number of null values in clientscnt_946L: 522902
# Number of null values in the combined clientscnt_946L: 0
# Number of null values in cntincpaycont9m_3716944L_right: 1136870
# Number of null values in cntincpaycont9m_3716944L: 844979
# Number of null values in the combined cntincpaycont9m_3716944L: 455190
# Number of null values in cntpmts24_3658933L_right: 1136846
# Number of null values in cntpmts24_3658933L: 850635
# Number of null values in the combined cntpmts24_3658933L: 460822
# Number of null values in commnoinclast6m_3546845L_right: 1087610
# Number of null values in commnoinclast6m_3546845L: 782424
# Number of null values in the combined commnoinclast6m_3546845L: 343375
# Number of null values in credamount_770A_right: 1003757
# Number of null values in credamount_770A: 522902
# Number of null values in the combined credamount_770A: 0
# Number of null values in credtype_322L_right: 1003757
# Number of null values in credtype_322L: 522903
# Number of null values in the combined credtype_322L: 1
# Number of null values in currdebt_22A_right: 1003759
# Number of null values in currdebt_22A: 522904
# Number of null values in the combined currdebt_22A: 4
# Number of null values in currdebtcredtyperange_828A_right: 1003759
# Number of null values in currdebtcredtyperange_828A: 522904
# Number of null values in the combined currdebtcredtyperange_828A: 4
# Number of null values in datefirstoffer_1144D_right: 1276779
# Number of null values in datefirstoffer_1144D: 1083615
# Number of null values in the combined datefirstoffer_1144D: 833735
# Number of null values in datelastinstal40dpd_247D_right: 1464334
# Number of null values in datelastinstal40dpd_247D: 1455166
# Number of null values in the combined datelastinstal40dpd_247D: 1392841
# Number of null values in datelastunpaid_3546854D_right: 1284666
# Number of null values in datelastunpaid_3546854D: 1129652
# Number of null values in the combined datelastunpaid_3546854D: 887659
# Number of null values in daysoverduetolerancedd_3976961L_right: 1136027
# Number of null values in daysoverduetolerancedd_3976961L: 843226
# Number of null values in the combined daysoverduetolerancedd_3976961L: 452594
# Number of null values in deferredmnthsnum_166L_right: 1003757
# Number of null values in deferredmnthsnum_166L: 522902
# Number of null values in the combined deferredmnthsnum_166L: 0
# Number of null values in disbursedcredamount_1113A_right: 1003757
# Number of null values in disbursedcredamount_1113A: 522902
# Number of null values in the combined disbursedcredamount_1113A: 0
# Number of null values in disbursementtype_67L_right: 1004005
# Number of null values in disbursementtype_67L: 523520
# Number of null values in the combined disbursementtype_67L: 866
# Number of null values in downpmt_116A_right: 1003757
# Number of null values in downpmt_116A: 522902
# Number of null values in the combined downpmt_116A: 0
# Number of null values in dtlastpmtallstes_4499206D_right: 1221972
# Number of null values in dtlastpmtallstes_4499206D: 1281806
# Number of null values in the combined dtlastpmtallstes_4499206D: 977119
# Number of null values in eir_270L_right: 1069077
# Number of null values in eir_270L: 648415
# Number of null values in the combined eir_270L: 190833
# Number of null values in equalitydataagreement_891L_right: 1500944
# Number of null values in equalitydataagreement_891L: 1474347
# Number of null values in the combined equalitydataagreement_891L: 1448632
# Number of null values in equalityempfrom_62L_right: 1517252
# Number of null values in equalityempfrom_62L: 1498254
# Number of null values in the combined equalityempfrom_62L: 1488847
# Number of null values in firstclxcampaign_1125D_right: 1291316
# Number of null values in firstclxcampaign_1125D: 1094557
# Number of null values in the combined firstclxcampaign_1125D: 859214
# Number of null values in firstdatedue_489D_right: 1146173
# Number of null values in firstdatedue_489D: 862589
# Number of null values in the combined firstdatedue_489D: 482103
# Number of null values in homephncnt_628L_right: 1003757
# Number of null values in homephncnt_628L: 522902
# Number of null values in the combined homephncnt_628L: 0
# Number of null values in inittransactionamount_650A_right: 1460226
# Number of null values in inittransactionamount_650A: 1400790
# Number of null values in the combined inittransactionamount_650A: 1334357
# Number of null values in inittransactioncode_186L_right: 1003757
# Number of null values in inittransactioncode_186L: 522903
# Number of null values in the combined inittransactioncode_186L: 1
# Number of null values in interestrate_311L_right: 1069077
# Number of null values in interestrate_311L: 648415
# Number of null values in the combined interestrate_311L: 190833
# Number of null values in interestrategrace_34L_right: 1522359
# Number of null values in interestrategrace_34L: 1510076
# Number of null values in the combined interestrategrace_34L: 1505776
# Number of null values in isbidproduct_1095L_right: 1003757
# Number of null values in isbidproduct_1095L: 522902
# Number of null values in the combined isbidproduct_1095L: 0
# Number of null values in isbidproductrequest_292L_right: 1522677
# Number of null values in isbidproductrequest_292L: 1518183
# Number of null values in the combined isbidproductrequest_292L: 1514201
# Number of null values in isdebitcard_729L_right: 1460226
# Number of null values in isdebitcard_729L: 1400790
# Number of null values in the combined isdebitcard_729L: 1334357
# Number of null values in lastactivateddate_801D_right: 1136502
# Number of null values in lastactivateddate_801D: 843744
# Number of null values in the combined lastactivateddate_801D: 453587
# Number of null values in lastapplicationdate_877D_right: 1088134
# Number of null values in lastapplicationdate_877D: 743662
# Number of null values in the combined lastapplicationdate_877D: 305137
# Number of null values in lastapprcommoditycat_1041M_right: 1003757
# Number of null values in lastapprcommoditycat_1041M: 522902
# Number of null values in the combined lastapprcommoditycat_1041M: 0
# Number of null values in lastapprcommoditytypec_5251766M_right: 1003757
# Number of null values in lastapprcommoditytypec_5251766M: 522902
# Number of null values in the combined lastapprcommoditytypec_5251766M: 0
# Number of null values in lastapprcredamount_781A_right: 1132675
# Number of null values in lastapprcredamount_781A: 836025
# Number of null values in the combined lastapprcredamount_781A: 442041
# Number of null values in lastapprdate_640D_right: 1132675
# Number of null values in lastapprdate_640D: 836025
# Number of null values in the combined lastapprdate_640D: 442041
# Number of null values in lastcancelreason_561M_right: 1003757
# Number of null values in lastcancelreason_561M: 522902
# Number of null values in the combined lastcancelreason_561M: 0
# Number of null values in lastdelinqdate_224D_right: 1313052
# Number of null values in lastdelinqdate_224D: 1191582
# Number of null values in the combined lastdelinqdate_224D: 977975
# Number of null values in lastdependentsnum_448L_right: 1522200
# Number of null values in lastdependentsnum_448L: 1501601
# Number of null values in the combined lastdependentsnum_448L: 1497142
# Number of null values in lastotherinc_902A_right: 1525831
# Number of null values in lastotherinc_902A: 1524431
# Number of null values in the combined lastotherinc_902A: 1523603
# Number of null values in lastotherlnsexpense_631A_right: 1525772
# Number of null values in lastotherlnsexpense_631A: 1524488
# Number of null values in the combined lastotherlnsexpense_631A: 1523601
# Number of null values in lastrejectcommoditycat_161M_right: 1003757
# Number of null values in lastrejectcommoditycat_161M: 522902
# Number of null values in the combined lastrejectcommoditycat_161M: 0
# Number of null values in lastrejectcommodtypec_5251769M_right: 1003757
# Number of null values in lastrejectcommodtypec_5251769M: 522902
# Number of null values in the combined lastrejectcommodtypec_5251769M: 0
# Number of null values in lastrejectcredamount_222A_right: 1241904
# Number of null values in lastrejectcredamount_222A: 1053801
# Number of null values in the combined lastrejectcredamount_222A: 769046
# Number of null values in lastrejectdate_50D_right: 1241904
# Number of null values in lastrejectdate_50D: 1053801
# Number of null values in the combined lastrejectdate_50D: 769046
# Number of null values in lastrejectreason_759M_right: 1003757
# Number of null values in lastrejectreason_759M: 522902
# Number of null values in the combined lastrejectreason_759M: 0
# Number of null values in lastrejectreasonclient_4145040M_right: 1003757
# Number of null values in lastrejectreasonclient_4145040M: 522902
# Number of null values in the combined lastrejectreasonclient_4145040M: 0
# Number of null values in lastrepayingdate_696D_right: 1525887
# Number of null values in lastrepayingdate_696D: 1525054
# Number of null values in the combined lastrepayingdate_696D: 1524282
# Number of null values in lastst_736L_right: 1088134
# Number of null values in lastst_736L: 743662
# Number of null values in the combined lastst_736L: 305137
# Number of null values in maininc_215A_right: 1174062
# Number of null values in maininc_215A: 863852
# Number of null values in the combined maininc_215A: 511255
# Number of null values in mastercontrelectronic_519L_right: 1087610
# Number of null values in mastercontrelectronic_519L: 745068
# Number of null values in the combined mastercontrelectronic_519L: 306019
# Number of null values in mastercontrexist_109L_right: 1087610
# Number of null values in mastercontrexist_109L: 745068
# Number of null values in the combined mastercontrexist_109L: 306019
# Number of null values in maxannuity_159A_right: 1087610
# Number of null values in maxannuity_159A: 745068
# Number of null values in the combined maxannuity_159A: 306019
# Number of null values in maxannuity_4075009A_right: 1500848
# Number of null values in maxannuity_4075009A: 1476537
# Number of null values in the combined maxannuity_4075009A: 1450726
# Number of null values in maxdbddpdlast1m_3658939P_right: 1321793
# Number of null values in maxdbddpdlast1m_3658939P: 1165819
# Number of null values in the combined maxdbddpdlast1m_3658939P: 960953
# Number of null values in maxdbddpdtollast12m_3658940P_right: 1226089
# Number of null values in maxdbddpdtollast12m_3658940P: 1006074
# Number of null values in the combined maxdbddpdtollast12m_3658940P: 705504
# Number of null values in maxdbddpdtollast6m_4187119P_right: 1263198
# Number of null values in maxdbddpdtollast6m_4187119P: 1139737
# Number of null values in the combined maxdbddpdtollast6m_4187119P: 876276
# Number of null values in maxdebt4_972A_right: 1087610
# Number of null values in maxdebt4_972A: 745068
# Number of null values in the combined maxdebt4_972A: 306019
# Number of null values in maxdpdfrom6mto36m_3546853P_right: 1087610
# Number of null values in maxdpdfrom6mto36m_3546853P: 782424
# Number of null values in the combined maxdpdfrom6mto36m_3546853P: 343375
# Number of null values in maxdpdinstldate_3546855D_right: 1261949
# Number of null values in maxdpdinstldate_3546855D: 1090710
# Number of null values in the combined maxdpdinstldate_3546855D: 826000
# Number of null values in maxdpdinstlnum_3546846P_right: 1264174
# Number of null values in maxdpdinstlnum_3546846P: 1091887
# Number of null values in the combined maxdpdinstlnum_3546846P: 829402
# Number of null values in maxdpdlast12m_727P_right: 1087610
# Number of null values in maxdpdlast12m_727P: 745068
# Number of null values in the combined maxdpdlast12m_727P: 306019
# Number of null values in maxdpdlast24m_143P_right: 1087610
# Number of null values in maxdpdlast24m_143P: 745068
# Number of null values in the combined maxdpdlast24m_143P: 306019
# Number of null values in maxdpdlast3m_392P_right: 1087610
# Number of null values in maxdpdlast3m_392P: 745068
# Number of null values in the combined maxdpdlast3m_392P: 306019
# Number of null values in maxdpdlast6m_474P_right: 1087610
# Number of null values in maxdpdlast6m_474P: 745068
# Number of null values in the combined maxdpdlast6m_474P: 306019
# Number of null values in maxdpdlast9m_1059P_right: 1087610
# Number of null values in maxdpdlast9m_1059P: 745068
# Number of null values in the combined maxdpdlast9m_1059P: 306019
# Number of null values in maxdpdtolerance_374P_right: 1087610
# Number of null values in maxdpdtolerance_374P: 745068
# Number of null values in the combined maxdpdtolerance_374P: 306019
# Number of null values in maxinstallast24m_3658928A_right: 1194911
# Number of null values in maxinstallast24m_3658928A: 956623
# Number of null values in the combined maxinstallast24m_3658928A: 624875
# Number of null values in maxlnamtstart6m_4525199A_right: 1229152
# Number of null values in maxlnamtstart6m_4525199A: 1330363
# Number of null values in the combined maxlnamtstart6m_4525199A: 1032856
# Number of null values in maxoutstandbalancel12m_4187113A_right: 1215519
# Number of null values in maxoutstandbalancel12m_4187113A: 1078098
# Number of null values in the combined maxoutstandbalancel12m_4187113A: 766958
# Number of null values in maxpmtlast3m_4525190A_right: 1287096
# Number of null values in maxpmtlast3m_4525190A: 1368893
# Number of null values in the combined maxpmtlast3m_4525190A: 1129330
# Number of null values in mindbddpdlast24m_3658935P_right: 1190828
# Number of null values in mindbddpdlast24m_3658935P: 949033
# Number of null values in the combined mindbddpdlast24m_3658935P: 613202
# Number of null values in mindbdtollast24m_4525191P_right: 1190859
# Number of null values in mindbdtollast24m_4525191P: 1308627
# Number of null values in the combined mindbdtollast24m_4525191P: 972827
# Number of null values in mobilephncnt_593L_right: 1003757
# Number of null values in mobilephncnt_593L: 522902
# Number of null values in the combined mobilephncnt_593L: 0
# Number of null values in monthsannuity_845L_right: 1136027
# Number of null values in monthsannuity_845L: 843225
# Number of null values in the combined monthsannuity_845L: 452593
# Number of null values in numactivecreds_622L_right: 1003757
# Number of null values in numactivecreds_622L: 522902
# Number of null values in the combined numactivecreds_622L: 0
# Number of null values in numactivecredschannel_414L_right: 1003757
# Number of null values in numactivecredschannel_414L: 522902
# Number of null values in the combined numactivecredschannel_414L: 0
# Number of null values in numactiverelcontr_750L_right: 1003757
# Number of null values in numactiverelcontr_750L: 522902
# Number of null values in the combined numactiverelcontr_750L: 0
# Number of null values in numcontrs3months_479L_right: 1003757
# Number of null values in numcontrs3months_479L: 522902
# Number of null values in the combined numcontrs3months_479L: 0
# Number of null values in numincomingpmts_3546848L_right: 1136846
# Number of null values in numincomingpmts_3546848L: 844894
# Number of null values in the combined numincomingpmts_3546848L: 455081
# Number of null values in numinstlallpaidearly3d_817L_right: 1134037
# Number of null values in numinstlallpaidearly3d_817L: 838291
# Number of null values in the combined numinstlallpaidearly3d_817L: 445669
# Number of null values in numinstls_657L_right: 1003759
# Number of null values in numinstls_657L: 522904
# Number of null values in the combined numinstls_657L: 4
# Number of null values in numinstlsallpaid_934L_right: 1134037
# Number of null values in numinstlsallpaid_934L: 838291
# Number of null values in the combined numinstlsallpaid_934L: 445669
# Number of null values in numinstlswithdpd10_728L_right: 1137259
# Number of null values in numinstlswithdpd10_728L: 845895
# Number of null values in the combined numinstlswithdpd10_728L: 456495
# Number of null values in numinstlswithdpd5_4187116L_right: 1136027
# Number of null values in numinstlswithdpd5_4187116L: 951756
# Number of null values in the combined numinstlswithdpd5_4187116L: 561124
# Number of null values in numinstlswithoutdpd_562L_right: 1137259
# Number of null values in numinstlswithoutdpd_562L: 845895
# Number of null values in the combined numinstlswithoutdpd_562L: 456495
# Number of null values in numinstmatpaidtearly2d_4499204L_right: 1136027
# Number of null values in numinstmatpaidtearly2d_4499204L: 1237823
# Number of null values in the combined numinstmatpaidtearly2d_4499204L: 847191
# Number of null values in numinstpaid_4499208L_right: 1136027
# Number of null values in numinstpaid_4499208L: 1237823
# Number of null values in the combined numinstpaid_4499208L: 847191
# Number of null values in numinstpaidearly3d_3546850L_right: 1134037
# Number of null values in numinstpaidearly3d_3546850L: 839605
# Number of null values in the combined numinstpaidearly3d_3546850L: 446983
# Number of null values in numinstpaidearly3dest_4493216L_right: 1136027
# Number of null values in numinstpaidearly3dest_4493216L: 1231278
# Number of null values in the combined numinstpaidearly3dest_4493216L: 840646
# Number of null values in numinstpaidearly5d_1087L_right: 1136027
# Number of null values in numinstpaidearly5d_1087L: 843225
# Number of null values in the combined numinstpaidearly5d_1087L: 452593
# Number of null values in numinstpaidearly5dest_4493211L_right: 1136027
# Number of null values in numinstpaidearly5dest_4493211L: 1231278
# Number of null values in the combined numinstpaidearly5dest_4493211L: 840646
# Number of null values in numinstpaidearly5dobd_4499205L_right: 1136027
# Number of null values in numinstpaidearly5dobd_4499205L: 1237823
# Number of null values in the combined numinstpaidearly5dobd_4499205L: 847191
# Number of null values in numinstpaidearly_338L_right: 1136027
# Number of null values in numinstpaidearly_338L: 843225
# Number of null values in the combined numinstpaidearly_338L: 452593
# Number of null values in numinstpaidearlyest_4493214L_right: 1136027
# Number of null values in numinstpaidearlyest_4493214L: 1231278
# Number of null values in the combined numinstpaidearlyest_4493214L: 840646
# Number of null values in numinstpaidlastcontr_4325080L_right: 1136027
# Number of null values in numinstpaidlastcontr_4325080L: 1059818
# Number of null values in the combined numinstpaidlastcontr_4325080L: 669186
# Number of null values in numinstpaidlate1d_3546852L_right: 1136027
# Number of null values in numinstpaidlate1d_3546852L: 843225
# Number of null values in the combined numinstpaidlate1d_3546852L: 452593
# Number of null values in numinstregularpaid_973L_right: 1136027
# Number of null values in numinstregularpaid_973L: 846244
# Number of null values in the combined numinstregularpaid_973L: 455612
# Number of null values in numinstregularpaidest_4493210L_right: 1136027
# Number of null values in numinstregularpaidest_4493210L: 1231278
# Number of null values in the combined numinstregularpaidest_4493210L: 840646
# Number of null values in numinsttopaygr_769L_right: 1136027
# Number of null values in numinsttopaygr_769L: 843226
# Number of null values in the combined numinsttopaygr_769L: 452594
# Number of null values in numinsttopaygrest_4493213L_right: 1136027
# Number of null values in numinsttopaygrest_4493213L: 1231278
# Number of null values in the combined numinsttopaygrest_4493213L: 840646
# Number of null values in numinstunpaidmax_3546851L_right: 1136027
# Number of null values in numinstunpaidmax_3546851L: 843226
# Number of null values in the combined numinstunpaidmax_3546851L: 452594
# Number of null values in numinstunpaidmaxest_4493212L_right: 1136027
# Number of null values in numinstunpaidmaxest_4493212L: 1231278
# Number of null values in the combined numinstunpaidmaxest_4493212L: 840646
# Number of null values in numnotactivated_1143L_right: 1003757
# Number of null values in numnotactivated_1143L: 522902
# Number of null values in the combined numnotactivated_1143L: 0
# Number of null values in numpmtchanneldd_318L_right: 1003757
# Number of null values in numpmtchanneldd_318L: 522902
# Number of null values in the combined numpmtchanneldd_318L: 0
# Number of null values in numrejects9m_859L_right: 1003757
# Number of null values in numrejects9m_859L: 522902
# Number of null values in the combined numrejects9m_859L: 0
# Number of null values in opencred_647L_right: 1088134
# Number of null values in opencred_647L: 743662
# Number of null values in the combined opencred_647L: 305137
# Number of null values in paytype1st_925L_right: 1061271
# Number of null values in paytype1st_925L: 523963
# Number of null values in the combined paytype1st_925L: 58575
# Number of null values in paytype_783L_right: 1061271
# Number of null values in paytype_783L: 523963
# Number of null values in the combined paytype_783L: 58575
# Number of null values in payvacationpostpone_4187118D_right: 1518797
# Number of null values in payvacationpostpone_4187118D: 1525192
# Number of null values in the combined payvacationpostpone_4187118D: 1517330
# Number of null values in pctinstlsallpaidearl3d_427L_right: 1138452
# Number of null values in pctinstlsallpaidearl3d_427L: 846945
# Number of null values in the combined pctinstlsallpaidearl3d_427L: 458738
# Number of null values in pctinstlsallpaidlat10d_839L_right: 1139228
# Number of null values in pctinstlsallpaidlat10d_839L: 848793
# Number of null values in the combined pctinstlsallpaidlat10d_839L: 461362
# Number of null values in pctinstlsallpaidlate1d_3546856L_right: 1138452
# Number of null values in pctinstlsallpaidlate1d_3546856L: 846945
# Number of null values in the combined pctinstlsallpaidlate1d_3546856L: 458738
# Number of null values in pctinstlsallpaidlate4d_3546849L_right: 1138804
# Number of null values in pctinstlsallpaidlate4d_3546849L: 847682
# Number of null values in the combined pctinstlsallpaidlate4d_3546849L: 459827
# Number of null values in pctinstlsallpaidlate6d_3546844L_right: 1138870
# Number of null values in pctinstlsallpaidlate6d_3546844L: 847868
# Number of null values in the combined pctinstlsallpaidlate6d_3546844L: 460079
# Number of null values in pmtnum_254L_right: 1020057
# Number of null values in pmtnum_254L: 551556
# Number of null values in the combined pmtnum_254L: 44954
# Number of null values in posfpd10lastmonth_333P_right: 1063091
# Number of null values in posfpd10lastmonth_333P: 542094
# Number of null values in the combined posfpd10lastmonth_333P: 78526
# Number of null values in posfpd30lastmonth_3976960P_right: 1071851
# Number of null values in posfpd30lastmonth_3976960P: 586696
# Number of null values in the combined posfpd30lastmonth_3976960P: 131888
# Number of null values in posfstqpd30lastmonth_3976962P_right: 1092425
# Number of null values in posfstqpd30lastmonth_3976962P: 615356
# Number of null values in the combined posfstqpd30lastmonth_3976962P: 181122
# Number of null values in previouscontdistrict_112M_right: 1003757
# Number of null values in previouscontdistrict_112M: 522902
# Number of null values in the combined previouscontdistrict_112M: 0
# Number of null values in price_1097A_right: 1092625
# Number of null values in price_1097A: 657274
# Number of null values in the combined price_1097A: 223240
# Number of null values in sellerplacecnt_915L_right: 1003757
# Number of null values in sellerplacecnt_915L: 522902
# Number of null values in the combined sellerplacecnt_915L: 0
# Number of null values in sellerplacescnt_216L_right: 1003757
# Number of null values in sellerplacescnt_216L: 522902
# Number of null values in the combined sellerplacescnt_216L: 0
# Number of null values in sumoutstandtotal_3546847A_right: 1133258
# Number of null values in sumoutstandtotal_3546847A: 838721
# Number of null values in the combined sumoutstandtotal_3546847A: 445320
# Number of null values in sumoutstandtotalest_4493215A_right: 1136027
# Number of null values in sumoutstandtotalest_4493215A: 1231278
# Number of null values in the combined sumoutstandtotalest_4493215A: 840646
# Number of null values in totaldebt_9A_right: 1003758
# Number of null values in totaldebt_9A: 522904
# Number of null values in the combined totaldebt_9A: 3
# Number of null values in totalsettled_863A_right: 1003759
# Number of null values in totalsettled_863A: 522904
# Number of null values in the combined totalsettled_863A: 4
# Number of null values in totinstallast1m_4525188A_right: 1312903
# Number of null values in totinstallast1m_4525188A: 1387967
# Number of null values in the combined totinstallast1m_4525188A: 1174211
# Number of null values in twobodfilling_608L_right: 1003803
# Number of null values in twobodfilling_608L: 522947
# Number of null values in the combined twobodfilling_608L: 91
# Number of null values in typesuite_864L_right: 1410025
# Number of null values in typesuite_864L: 1238139
# Number of null values in the combined typesuite_864L: 1121505
# Number of null values in validfrom_1069D_right: 1494291
# Number of null values in validfrom_1069D: 1407254
# Number of null values in the combined validfrom_1069D: 1374886

# %%
# Send the depth 0 dataframe to a parquet file
data.write_parquet(dataPath + "depth0_df.parquet")

# %%
# Find the columns ending in P as they are the days past due columns
dpd_columns = [col for col in data.columns if col.endswith("P")]
dpd_columns = pl.DataFrame({'feature_name':dpd_columns})
# Add the column name feature_name to the feature_def dataframe
feature_def.columns = ["feature_name", "description"]
# Join the feature definitions to the dpd columns
dpd_columns_names = dpd_columns.join(feature_def, on="feature_name", how="left")
dpd_columns_names.head()
# Out:
# shape: (5, 2)
# ┌─────────────────────────────┬───────────────────────────────────┐
# │ feature_name                ┆ description                       │
# │ ---                         ┆ ---                               │
# │ str                         ┆ str                               │
# ╞═════════════════════════════╪═══════════════════════════════════╡
# │ actualdpdtolerance_344P     ┆ DPD of client with tolerance.     │
# │ avgdbddpdlast24m_3658932P   ┆ Average days past or before due … │
# │ avgdbddpdlast3m_4187120P    ┆ Average days past or before due … │
# │ avgdbdtollast24m_4525197P   ┆ Average days of payment before d… │
# │ avgdpdtolclosure24_3658938P ┆ Average DPD (days past due) with… │
# └─────────────────────────────┴───────────────────────────────────┘

# %%
# Lets try making a dataframe of the payment history only and see if we can predict the target, might be a path to ensembling
# Create a dataframe of the payment history
payment_history = data.select(dpd_columns_names['feature_name'].to_list() + ["target"] + ["case_id"] + ["WEEK_NUM"])

# %%
# Make a test run with data as the payment history
data = payment_history

# %% [markdown]
# ### Modelling

# %%
case_ids = data["case_id"].unique().shuffle(seed=1)
case_ids_train, case_ids_valid = train_test_split(case_ids, train_size=0.8, random_state=1)


cols_pred = []
for col in data.columns:
    if col[-1].isupper() and col[:-1].islower():
        cols_pred.append(col)

print(cols_pred)

def from_polars_to_pandas(case_ids: pl.DataFrame) -> pl.DataFrame:
    return (
        data.filter(pl.col("case_id").is_in(case_ids))[["case_id", "WEEK_NUM", "target"]].to_pandas(),
        data.filter(pl.col("case_id").is_in(case_ids))[cols_pred].to_pandas(),
        data.filter(pl.col("case_id").is_in(case_ids))["target"].to_pandas().ravel()
    )

base_train, X_train, y_train = from_polars_to_pandas(case_ids_train)
base_valid, X_valid, y_valid = from_polars_to_pandas(case_ids_valid)


# for df in [X_train, X_valid, X_test]:
#     df = Pipeline.convert_strings(df)
# Out:
# ['actualdpdtolerance_344P', 'avgdbddpdlast24m_3658932P', 'avgdbddpdlast3m_4187120P', 'avgdbdtollast24m_4525197P', 'avgdpdtolclosure24_3658938P', 'avgmaxdpdlast9m_3716943P', 'maxdbddpdlast1m_3658939P', 'maxdbddpdtollast12m_3658940P', 'maxdbddpdtollast6m_4187119P', 'maxdpdfrom6mto36m_3546853P', 'maxdpdinstlnum_3546846P', 'maxdpdlast12m_727P', 'maxdpdlast24m_143P', 'maxdpdlast3m_392P', 'maxdpdlast6m_474P', 'maxdpdlast9m_1059P', 'maxdpdtolerance_374P', 'mindbddpdlast24m_3658935P', 'mindbdtollast24m_4525191P', 'posfpd10lastmonth_333P', 'posfpd30lastmonth_3976960P', 'posfstqpd30lastmonth_3976962P']

# %%
print(f"Train: {X_train.shape}")
print(f"Valid: {X_valid.shape}")
print(f"Test: {X_test.shape}")
# Out:
# Train: (915995, 22)
# Valid: (305332, 22)
# Test: (305332, 22)

# %%
import optuna

# override Optuna's default logging to ERROR only
optuna.logging.set_verbosity(optuna.logging.ERROR)

# define a logging callback that will report on only new challenger parameter configurations if a
# trial has usurped the state of 'best conditions'


def champion_callback(study, frozen_trial):
    """
    Logging callback that will report when a new trial iteration improves upon existing
    best trial values.
    """

    winner = study.user_attrs.get("winner", None)

    if study.best_value and winner != study.best_value:
        study.set_user_attr("winner", study.best_value)
        if winner:
            improvement_percent = (abs(winner - study.best_value) / study.best_value) * 100
            print(
                f"Trial {frozen_trial.number} achieved value: {frozen_trial.value} with "
                f"{improvement_percent: .4f}% improvement"
            )
        else:
            print(f"Initial trial {frozen_trial.number} achieved value: {frozen_trial.value}")

# %%
# Create a dataset for lightgbm
lgb_train = lgb.Dataset(X_train, label=y_train)
lgb_valid = lgb.Dataset(X_valid, label=y_valid, reference=lgb_train)

# Define the objective function for Optuna
def objective(trial):
    with mlflow.start_run(nested=True):
        param = {
            "boosting_type": trial.suggest_categorical("boosting_type", ["gbdt", "rf"]),
            "objective": "binary",
            "metric": "auc",
            "max_depth": trial.suggest_int("max_depth", 1, 10),
            "num_leaves": trial.suggest_int("num_leaves", 20, 60),
            "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.2),
            "feature_fraction": trial.suggest_float("feature_fraction", 0.6, 1.0),
            "bagging_fraction": trial.suggest_float("bagging_fraction", 0.6, 1.0),
            "bagging_freq": trial.suggest_int("bagging_freq", 1, 10),
            "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
            "lambda_l1": trial.suggest_loguniform("lambda_l1", 1e-8, 10.0),
            "lambda_l2": trial.suggest_loguniform("lambda_l2", 1e-8, 10.0),
            "n_estimators": 1000,
            "verbose": -1,
            "feature_pre_filter": False,  # Explicitly disabling feature pre-filtering
        }
        
        gbm = lgb.train(
            param,
            lgb_train,
            valid_sets=lgb_valid,
            callbacks=[lgb.log_evaluation(50), lgb.early_stopping(10)]
        )
        
        preds = gbm.predict(X_valid)
        auc = roc_auc_score(y_valid, preds)
        
        # Log to MLflow
        mlflow.log_params(param)
        mlflow.log_metric("auc", auc)
    return auc

# %%
def gini_stability(base, w_fallingrate=88.0, w_resstd=-0.5):
    gini_in_time = base.loc[:, ["WEEK_NUM", "target", "score"]]\
        .sort_values("WEEK_NUM")\
        .groupby("WEEK_NUM")[["target", "score"]]\
        .apply(lambda x: 2*roc_auc_score(x["target"], x["score"])-1).tolist()
    
    x = np.arange(len(gini_in_time))
    y = gini_in_time
    a, b = np.polyfit(x, y, 1)
    y_hat = a*x + b
    residuals = y - y_hat
    res_std = np.std(residuals)
    avg_gini = np.mean(gini_in_time)
    return avg_gini + w_fallingrate * min(0, a) + w_resstd * res_std

# %% [markdown]
# ## MLFLOW TRAIN AND LOG

# %%
# Initiate the parent run and call the hyperparameter tuning child run logic
with mlflow.start_run(experiment_id=experiment_id, run_name=run_name, nested=True):
    # Initialize the Optuna study
    study = optuna.create_study(direction="maximize")
    study.optimize(objective, n_trials=10, callbacks=[champion_callback])  
        
    # Log the best hyperparameters to MLflow
    mlflow.log_params(study.best_params)
    mlflow.log_metric("AUC", study.best_value)
        
    # Log tags
    mlflow.set_tags(
        tags={
            "project": "Kaggle Home Credit Default Risk",
            "optimizer_engine": "optuna",
            "model_family": "lgbm",
            "feature_set_version": 2,
        }
    )

    # Fit model instance
    model = lgb.train(study.best_params, lgb_train)

    # Add the preditions to the base table
    base_train["score"] = model.predict(X_train)
    
    # Calc the gini stability score
    stability_score_train = gini_stability(base_train)
    
    # Log the gini stability score to MLflow
    mlflow.log_metric("gini_stability", stability_score_train)
    
    # Log the model to MLflow    
    artifact_path = "model"

    mlflow.lightgbm.log_model(model, artifact_path)

    # Get the logged model uri so that we can load it from the artifact store
    model_uri = mlflow.get_artifact_uri(artifact_path)
# Out:
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [14]	valid_0's auc: 0.64163
# Initial trial 0 achieved value: 0.6416304757297406
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [14]	valid_0's auc: 0.651476
# Trial 1 achieved value: 0.6514760155598909 with  1.5113% improvement
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [25]	valid_0's auc: 0.660212
# Trial 2 achieved value: 0.6602118632695736 with  1.3232% improvement
# Training until validation scores don't improve for 10 rounds
# [50]	valid_0's auc: 0.693843
# Early stopping, best iteration is:
# [59]	valid_0's auc: 0.694219
# Trial 3 achieved value: 0.6942190563856229 with  4.8986% improvement
# Training until validation scores don't improve for 10 rounds
# [50]	valid_0's auc: 0.692583
# Early stopping, best iteration is:
# [47]	valid_0's auc: 0.692672
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [25]	valid_0's auc: 0.692418
# Training until validation scores don't improve for 10 rounds
# [50]	valid_0's auc: 0.693145
# [100]	valid_0's auc: 0.693899
# Early stopping, best iteration is:
# [91]	valid_0's auc: 0.693932
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [37]	valid_0's auc: 0.655975
# Training until validation scores don't improve for 10 rounds
# [50]	valid_0's auc: 0.685638
# Early stopping, best iteration is:
# [41]	valid_0's auc: 0.685826
# Training until validation scores don't improve for 10 rounds
# [50]	valid_0's auc: 0.693608
# Early stopping, best iteration is:
# [74]	valid_0's auc: 0.69421
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.017290 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4259
# [LightGBM] [Info] Number of data points in the train set: 915995, number of used features: 22
# [LightGBM] [Info] Start training from score 0.031520
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
def gini_stability(base, w_fallingrate=88.0, w_resstd=-0.5):
    gini_in_time = base.loc[:, ["WEEK_NUM", "target", "score"]]\
        .sort_values("WEEK_NUM")\
        .groupby("WEEK_NUM")[["target", "score"]]\
        .apply(lambda x: 2*roc_auc_score(x["target"], x["score"])-1).tolist()
    
    x = np.arange(len(gini_in_time))
    y = gini_in_time
    a, b = np.polyfit(x, y, 1)
    y_hat = a*x + b
    residuals = y - y_hat
    res_std = np.std(residuals)
    avg_gini = np.mean(gini_in_time)
    return avg_gini + w_fallingrate * min(0, a) + w_resstd * res_std

stability_score_train = gini_stability(base_train)
stability_score_valid = gini_stability(base_valid)


print(f'The stability score on the train set is: {stability_score_train}') 
print(f'The stability score on the valid set is: {stability_score_valid}')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 17
#      14     return avg_gini + w_fallingrate * min(0, a) + w_resstd * res_std
#      16 stability_score_train = gini_stability(base_train)
# ---> 17 stability_score_valid = gini_stability(base_valid)
#      18 stability_score_test = gini_stability(base_test)
#      20 print(f'The stability score on the train set is: {stability_score_train}')
#
# Cell In[20], line 2, in gini_stability(base, w_fallingrate, w_resstd)
#       1 def gini_stability(base, w_fallingrate=88.0, w_resstd=-0.5):
# ----> 2     gini_in_time = base.loc[:, ["WEEK_NUM", "target", "score"]]\
#       3         .sort_values("WEEK_NUM")\
#       4         .groupby("WEEK_NUM")[["target", "score"]]\
#       5         .apply(lambda x: 2*roc_auc_score(x["target"], x["score"])-1).tolist()
#       7     x = np.arange(len(gini_in_time))
#       8     y = gini_in_time
#
# File ~/miniforge3/envs/AutoGPTENV/lib/python3.10/site-packages/pandas/core/indexing.py:1147, in _LocationIndexer.__getitem__(self, key)
#    1145     if self._is_scalar_access(key):
#    1146         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1147     return self._getitem_tuple(key)
#    1148 else:
#    1149     # we by definition only have the 0th axis
#    1150     axis = self.axis or 0
#
# File ~/miniforge3/envs/AutoGPTENV/lib/python3.10/site-packages/pandas/core/indexing.py:1339, in _LocIndexer._getitem_tuple(self, tup)
#    1336 if self._multi_take_opportunity(tup):
#    1337     return self._multi_take(tup)
# -> 1339 return self._getitem_tuple_same_dim(tup)
#
# File ~/miniforge3/envs/AutoGPTENV/lib/python3.10/site-packages/pandas/core/indexing.py:994, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
#     991 if com.is_null_slice(key):
#     992     continue
# --> 994 retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     995 # We should never have retval.ndim < self.ndim, as that should
#     996 #  be handled by the _getitem_lowerdim call above.
#     997 assert retval.ndim == self.ndim
#
# File ~/miniforge3/envs/AutoGPTENV/lib/python3.10/site-packages/pandas/core/indexing.py:1382, in _LocIndexer._getitem_axis(self, key, axis)
#    1379     if hasattr(key, "ndim") and key.ndim > 1:
#    1380         raise ValueError("Cannot index with multidimensional key")
# -> 1382     return self._getitem_iterable(key, axis=axis)
#    1384 # nested tuple slicing
#    1385 if is_nested_tuple(key, labels):
#
# File ~/miniforge3/envs/AutoGPTENV/lib/python3.10/site-packages/pandas/core/indexing.py:1322, in _LocIndexer._getitem_iterable(self, key, axis)
#    1319 self._validate_key(key, axis)
#    1321 # A collection of keys
# -> 1322 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1323 return self.obj._reindex_with_indexers(
#    1324     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1325 )
#
# File ~/miniforge3/envs/AutoGPTENV/lib/python3.10/site-packages/pandas/core/indexing.py:1520, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1517 ax = self.obj._get_axis(axis)
#    1518 axis_name = self.obj._get_axis_name(axis)
# -> 1520 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1522 return keyarr, indexer
#
# File ~/miniforge3/envs/AutoGPTENV/lib/python3.10/site-packages/pandas/core/indexes/base.py:6114, in Index._get_indexer_strict(self, key, axis_name)
#    6111 else:
#    6112     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6114 self._raise_if_missing(keyarr, indexer, axis_name)
#    6116 keyarr = self.take(indexer)
#    6117 if isinstance(key, Index):
#    6118     # GH 42790 - Preserve name from an Index
#
# File ~/miniforge3/envs/AutoGPTENV/lib/python3.10/site-packages/pandas/core/indexes/base.py:6178, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6175     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6177 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6178 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['score'] not in index"

# %% [markdown]
# ## Submission

# %%
# Load the sample submission file
sub_df = pd.read_csv(dataPath + "sample_submission.csv")
# Generate the predictions from the test files

sub_df = sub_df.set_index("case_id")
sub_df['score'] =
